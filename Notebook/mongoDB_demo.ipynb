# %%
import pandas as pd
import pymongo

df = pd.read_excel('data_excel.xlsx')
df.head(10)
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1           28                   0
# 1   2    Male   76                1            3                   0
# 2   3    Male   47                1           28                   0
# 3   4    Male   21                1           11                   1
# 4   5  Female   29                1           41                   1
# 5   6  Female   24                1           33                   0
# 6   7    Male   23                1           11                   0
# 7   8  Female   56                1           28                   0
# 8   9  Female   24                1            3                   1
# 9  10  Female   32                1            6                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes           40454                    26      217
# 1    1-2 Year             No           33536                    26      183
# 2   > 2 Years            Yes           38294                    26       27
# 3    < 1 Year             No           28619                   152      203
# 4    < 1 Year             No           27496                   152       39
# 5    < 1 Year            Yes            2630                   160      176
# 6    < 1 Year            Yes           23367                   152      249
# 7    1-2 Year            Yes           32031                    26       72
# 8    < 1 Year             No           27619                   152       28
# 9    < 1 Year             No           28771                   152       80
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0
# 5         0
# 6         0
# 7         1
# 8         0
# 9         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
data
# Out:
# [{'id': 1,
#   'Gender': 'Male',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 40454,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 217,
#   'Response': 1},
#  {'id': 2,
#   'Gender': 'Male',
#   'Age': 76,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 33536,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 183,
#   'Response': 0},
#  {'id': 3,
#   'Gender': 'Male',
#   'Age': 47,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 38294,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 27,
#   'Response': 1},
#  {'id': 4,
#   'Gender': 'Male',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 11,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 28619,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 203,
#   'Response': 0},
#  {'id': 5,
#   'Gender': 'Female',
#   'Age': 29,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27496,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 39,
#   'Response': 0},
#  {'id': 6,
#   'Gender': 'Female',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 33,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 176,
#   'Response': 0},
#  {'id': 7,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 11,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 23367,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 249,
#   'Response': 0},
#  {'id': 8,
#   'Gender': 'Female',
#   'Age': 56,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32031,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 72,
#   'Response': 1},
#  {'id': 9,
#   'Gender': 'Female',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27619,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 28,
#   'Response': 0},
#  {'id': 10,
#   'Gender': 'Female',
#   'Age': 32,
#   'Driving_License': 1,
#   'Region_Code': 6,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 28771,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 80,
#   'Response': 0},
#  {'id': 11,
#   'Gender': 'Female',
#   'Age': 47,
#   'Driving_License': 1,
#   'Region_Code': 35,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 47576,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 46,
#   'Response': 1},
#  {'id': 12,
#   'Gender': 'Female',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 50,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 48699,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 289,
#   'Response': 0},
#  {'id': 13,
#   'Gender': 'Female',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 15,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31409,
#   'Policy_Sales_Channel': 14,
#   'Vintage': 221,
#   'Response': 0},
#  {'id': 14,
#   'Gender': 'Male',
#   'Age': 76,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 36770,
#   'Policy_Sales_Channel': 13,
#   'Vintage': 15,
#   'Response': 0},
#  {'id': 15,
#   'Gender': 'Male',
#   'Age': 71,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 46818,
#   'Policy_Sales_Channel': 30,
#   'Vintage': 58,
#   'Response': 0},
#  {'id': 16,
#   'Gender': 'Male',
#   'Age': 37,
#   'Driving_License': 1,
#   'Region_Code': 6,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 156,
#   'Vintage': 147,
#   'Response': 1},
#  {'id': 17,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 45,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 26218,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 256,
#   'Response': 0},
#  {'id': 18,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 35,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 46622,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 299,
#   'Response': 0},
#  {'id': 19,
#   'Gender': 'Male',
#   'Age': 42,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 33667,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 158,
#   'Response': 0},
#  {'id': 20,
#   'Gender': 'Female',
#   'Age': 60,
#   'Driving_License': 1,
#   'Region_Code': 33,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32363,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 102,
#   'Response': 1},
#  {'id': 21,
#   'Gender': 'Male',
#   'Age': 65,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 41184,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 116,
#   'Response': 0},
#  {'id': 22,
#   'Gender': 'Male',
#   'Age': 49,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 50791,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 177,
#   'Response': 0},
#  {'id': 23,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 50,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 45283,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 232,
#   'Response': 0},
#  {'id': 24,
#   'Gender': 'Male',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 41852,
#   'Policy_Sales_Channel': 163,
#   'Vintage': 60,
#   'Response': 0},
#  {'id': 25,
#   'Gender': 'Male',
#   'Age': 34,
#   'Driving_License': 1,
#   'Region_Code': 15,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38111,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 180,
#   'Response': 0},
#  {'id': 26,
#   'Gender': 'Female',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 61964,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 72,
#   'Response': 0},
#  {'id': 27,
#   'Gender': 'Female',
#   'Age': 51,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 38341,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 49,
#   'Response': 1},
#  {'id': 28,
#   'Gender': 'Male',
#   'Age': 26,
#   'Driving_License': 1,
#   'Region_Code': 6,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 19135,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 57,
#   'Response': 0},
#  {'id': 29,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27946,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 223,
#   'Response': 0},
#  {'id': 30,
#   'Gender': 'Male',
#   'Age': 57,
#   'Driving_License': 1,
#   'Region_Code': 11,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 25679,
#   'Policy_Sales_Channel': 157,
#   'Vintage': 232,
#   'Response': 1},
#  {'id': 31,
#   'Gender': 'Female',
#   'Age': 26,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 136,
#   'Response': 0},
#  {'id': 32,
#   'Gender': 'Male',
#   'Age': 79,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 57444,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 222,
#   'Response': 0},
#  {'id': 33,
#   'Gender': 'Female',
#   'Age': 48,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 36951,
#   'Policy_Sales_Channel': 122,
#   'Vintage': 149,
#   'Response': 0},
#  {'id': 34,
#   'Gender': 'Female',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 36,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 43129,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 49,
#   'Response': 0},
#  {'id': 35,
#   'Gender': 'Female',
#   'Age': 32,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27638,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 169,
#   'Response': 0},
#  {'id': 36,
#   'Gender': 'Male',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 36,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 30039,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 88,
#   'Response': 0},
#  {'id': 37,
#   'Gender': 'Male',
#   'Age': 71,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40903,
#   'Policy_Sales_Channel': 19,
#   'Vintage': 253,
#   'Response': 0},
#  {'id': 38,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 76251,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 107,
#   'Response': 0},
#  {'id': 39,
#   'Gender': 'Male',
#   'Age': 45,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 42297,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 264,
#   'Response': 0},
#  {'id': 40,
#   'Gender': 'Male',
#   'Age': 72,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 32210,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 233,
#   'Response': 0},
#  {'id': 41,
#   'Gender': 'Male',
#   'Age': 30,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 24550,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 45,
#   'Response': 0},
#  {'id': 42,
#   'Gender': 'Female',
#   'Age': 54,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38560,
#   'Policy_Sales_Channel': 122,
#   'Vintage': 184,
#   'Response': 0},
#  {'id': 43,
#   'Gender': 'Male',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 21078,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 251,
#   'Response': 0},
#  {'id': 44,
#   'Gender': 'Female',
#   'Age': 38,
#   'Driving_License': 1,
#   'Region_Code': 35,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 153,
#   'Response': 0},
#  {'id': 45,
#   'Gender': 'Female',
#   'Age': 26,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31136,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 186,
#   'Response': 0},
#  {'id': 46,
#   'Gender': 'Male',
#   'Age': 56,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34617,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 71,
#   'Response': 0},
#  {'id': 47,
#   'Gender': 'Female',
#   'Age': 29,
#   'Driving_License': 1,
#   'Region_Code': 15,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 32923,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 34,
#   'Response': 0},
#  {'id': 48,
#   'Gender': 'Male',
#   'Age': 51,
#   'Driving_License': 1,
#   'Region_Code': 26,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 33761,
#   'Policy_Sales_Channel': 22,
#   'Vintage': 83,
#   'Response': 0},
#  {'id': 49,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 15,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38667,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 12,
#   'Response': 0},
#  {'id': 50,
#   'Gender': 'Male',
#   'Age': 48,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38233,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 246,
#   'Response': 0},
#  {'id': 51,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 50,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 15052,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 141,
#   'Response': 0},
#  {'id': 52,
#   'Gender': 'Male',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 16,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 30673,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 216,
#   'Response': 0},
#  {'id': 53,
#   'Gender': 'Female',
#   'Age': 49,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 25553,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 130,
#   'Response': 0},
#  {'id': 54,
#   'Gender': 'Male',
#   'Age': 78,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 49491,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 282,
#   'Response': 0},
#  {'id': 55,
#   'Gender': 'Female',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 45415,
#   'Policy_Sales_Channel': 13,
#   'Vintage': 73,
#   'Response': 0},
#  {'id': 56,
#   'Gender': 'Female',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 47,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 25380,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 171,
#   'Response': 0},
#  {'id': 57,
#   'Gender': 'Male',
#   'Age': 39,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 57582,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 141,
#   'Response': 0},
#  {'id': 58,
#   'Gender': 'Male',
#   'Age': 54,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 25205,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 283,
#   'Response': 1},
#  {'id': 59,
#   'Gender': 'Female',
#   'Age': 62,
#   'Driving_License': 1,
#   'Region_Code': 48,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 15,
#   'Vintage': 295,
#   'Response': 0},
#  {'id': 60,
#   'Gender': 'Male',
#   'Age': 29,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 35463,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 165,
#   'Response': 0},
#  {'id': 61,
#   'Gender': 'Male',
#   'Age': 49,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 156,
#   'Vintage': 30,
#   'Response': 0},
#  {'id': 62,
#   'Gender': 'Female',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 50,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 36615,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 218,
#   'Response': 0},
#  {'id': 63,
#   'Gender': 'Female',
#   'Age': 62,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 33830,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 130,
#   'Response': 0},
#  {'id': 64,
#   'Gender': 'Male',
#   'Age': 58,
#   'Driving_License': 1,
#   'Region_Code': 19,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 39661,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 141,
#   'Response': 0},
#  {'id': 65,
#   'Gender': 'Male',
#   'Age': 39,
#   'Driving_License': 1,
#   'Region_Code': 15,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 37849,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 22,
#   'Response': 0},
#  {'id': 66,
#   'Gender': 'Female',
#   'Age': 59,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34426,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 147,
#   'Response': 0},
#  {'id': 67,
#   'Gender': 'Male',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 42268,
#   'Policy_Sales_Channel': 154,
#   'Vintage': 36,
#   'Response': 0},
#  {'id': 68,
#   'Gender': 'Male',
#   'Age': 60,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 66338,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 73,
#   'Response': 0},
#  {'id': 69,
#   'Gender': 'Male',
#   'Age': 63,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 61739,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 79,
#   'Response': 0},
#  {'id': 70,
#   'Gender': 'Female',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 81,
#   'Response': 1},
#  {'id': 71,
#   'Gender': 'Male',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 47,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 46481,
#   'Policy_Sales_Channel': 16,
#   'Vintage': 100,
#   'Response': 0},
#  {'id': 72,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 11,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34587,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 63,
#   'Response': 0},
#  {'id': 73,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 39,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40372,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 242,
#   'Response': 0},
#  {'id': 74,
#   'Gender': 'Male',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27784,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 277,
#   'Response': 0},
#  {'id': 75,
#   'Gender': 'Male',
#   'Age': 59,
#   'Driving_License': 1,
#   'Region_Code': 23,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27865,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 39,
#   'Response': 0},
#  {'id': 76,
#   'Gender': 'Female',
#   'Age': 59,
#   'Driving_License': 1,
#   'Region_Code': 26,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 35649,
#   'Policy_Sales_Channel': 122,
#   'Vintage': 136,
#   'Response': 0},
#  {'id': 77,
#   'Gender': 'Male',
#   'Age': 67,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31993,
#   'Policy_Sales_Channel': 122,
#   'Vintage': 61,
#   'Response': 0},
#  {'id': 78,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 33,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 35512,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 111,
#   'Response': 0},
#  {'id': 79,
#   'Gender': 'Male',
#   'Age': 29,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 42567,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 167,
#   'Response': 1},
#  {'id': 80,
#   'Gender': 'Male',
#   'Age': 77,
#   'Driving_License': 1,
#   'Region_Code': 37,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40651,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 183,
#   'Response': 0},
#  {'id': 81,
#   'Gender': 'Male',
#   'Age': 54,
#   'Driving_License': 1,
#   'Region_Code': 26,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 35493,
#   'Policy_Sales_Channel': 22,
#   'Vintage': 74,
#   'Response': 0},
#  {'id': 82,
#   'Gender': 'Female',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38529,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 235,
#   'Response': 0},
#  {'id': 83,
#   'Gender': 'Female',
#   'Age': 39,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 34735,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 131,
#   'Response': 0},
#  {'id': 84,
#   'Gender': 'Female',
#   'Age': 39,
#   'Driving_License': 1,
#   'Region_Code': 5,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 31760,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 141,
#   'Response': 0},
#  {'id': 85,
#   'Gender': 'Male',
#   'Age': 69,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 29802,
#   'Policy_Sales_Channel': 122,
#   'Vintage': 158,
#   'Response': 0},
#  {'id': 86,
#   'Gender': 'Female',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 17,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 27756,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 243,
#   'Response': 0},
#  {'id': 87,
#   'Gender': 'Female',
#   'Age': 54,
#   'Driving_License': 1,
#   'Region_Code': 47,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32873,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 248,
#   'Response': 0},
#  {'id': 88,
#   'Gender': 'Male',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 23,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 23537,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 58,
#   'Response': 0},
#  {'id': 89,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 35,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27606,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 114,
#   'Response': 0},
#  {'id': 90,
#   'Gender': 'Female',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 36,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 46275,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 281,
#   'Response': 1},
#  {'id': 91,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 50,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31556,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 62,
#   'Response': 0},
#  {'id': 92,
#   'Gender': 'Female',
#   'Age': 26,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31791,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 189,
#   'Response': 0},
#  {'id': 93,
#   'Gender': 'Male',
#   'Age': 77,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 36099,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 139,
#   'Response': 0},
#  {'id': 94,
#   'Gender': 'Female',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 156,
#   'Vintage': 138,
#   'Response': 0},
#  {'id': 95,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 15,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 41641,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 209,
#   'Response': 0},
#  {'id': 96,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 26689,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 254,
#   'Response': 0},
#  {'id': 97,
#   'Gender': 'Male',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 46995,
#   'Policy_Sales_Channel': 52,
#   'Vintage': 291,
#   'Response': 0},
#  {'id': 98,
#   'Gender': 'Female',
#   'Age': 62,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 41892,
#   'Policy_Sales_Channel': 155,
#   'Vintage': 114,
#   'Response': 0},
#  {'id': 99,
#   'Gender': 'Female',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 2,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34274,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 79,
#   'Response': 0},
#  {'id': 100,
#   'Gender': 'Female',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 7,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 68,
#   'Response': 0},
#  {'id': 101,
#   'Gender': 'Male',
#   'Age': 52,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 36033,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 92,
#   'Response': 0},
#  {'id': 102,
#   'Gender': 'Male',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 28139,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 52,
#   'Response': 0},
#  {'id': 103,
#   'Gender': 'Female',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 33227,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 78,
#   'Response': 0},
#  {'id': 104,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 39816,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 156,
#   'Response': 0},
#  {'id': 105,
#   'Gender': 'Male',
#   'Age': 29,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 43046,
#   'Policy_Sales_Channel': 163,
#   'Vintage': 222,
#   'Response': 0},
#  {'id': 106,
#   'Gender': 'Female',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 50521,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 22,
#   'Response': 1},
#  {'id': 107,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 36674,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 158,
#   'Response': 0},
#  {'id': 108,
#   'Gender': 'Male',
#   'Age': 31,
#   'Driving_License': 1,
#   'Region_Code': 29,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 28867,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 247,
#   'Response': 0},
#  {'id': 109,
#   'Gender': 'Male',
#   'Age': 72,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 28698,
#   'Policy_Sales_Channel': 30,
#   'Vintage': 216,
#   'Response': 0},
#  {'id': 110,
#   'Gender': 'Male',
#   'Age': 45,
#   'Driving_License': 1,
#   'Region_Code': 35,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 275,
#   'Response': 0},
#  {'id': 111,
#   'Gender': 'Male',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31428,
#   'Policy_Sales_Channel': 122,
#   'Vintage': 77,
#   'Response': 0},
#  {'id': 112,
#   'Gender': 'Female',
#   'Age': 48,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 37379,
#   'Policy_Sales_Channel': 11,
#   'Vintage': 139,
#   'Response': 0},
#  {'id': 113,
#   'Gender': 'Female',
#   'Age': 33,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 24998,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 181,
#   'Response': 0},
#  {'id': 114,
#   'Gender': 'Male',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34271,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 229,
#   'Response': 1},
#  {'id': 115,
#   'Gender': 'Female',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 32830,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 275,
#   'Response': 0},
#  {'id': 116,
#   'Gender': 'Female',
#   'Age': 32,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34810,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 166,
#   'Response': 0},
#  {'id': 117,
#   'Gender': 'Male',
#   'Age': 69,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 11,
#   'Vintage': 16,
#   'Response': 0},
#  {'id': 118,
#   'Gender': 'Female',
#   'Age': 32,
#   'Driving_License': 1,
#   'Region_Code': 27,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 22838,
#   'Policy_Sales_Channel': 151,
#   'Vintage': 295,
#   'Response': 0},
#  {'id': 119,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 29,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 37983,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 23,
#   'Response': 0},
#  {'id': 120,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 25,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 149,
#   'Response': 0},
#  {'id': 121,
#   'Gender': 'Male',
#   'Age': 39,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 37239,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 216,
#   'Response': 1},
#  {'id': 122,
#   'Gender': 'Female',
#   'Age': 39,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 37243,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 31,
#   'Response': 0},
#  {'id': 123,
#   'Gender': 'Male',
#   'Age': 37,
#   'Driving_License': 1,
#   'Region_Code': 13,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 30440,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 293,
#   'Response': 0},
#  {'id': 124,
#   'Gender': 'Male',
#   'Age': 34,
#   'Driving_License': 1,
#   'Region_Code': 18,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 38232,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 156,
#   'Response': 1},
#  {'id': 125,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 15,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 25605,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 256,
#   'Response': 0},
#  {'id': 126,
#   'Gender': 'Male',
#   'Age': 49,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 88,
#   'Response': 0},
#  {'id': 127,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 33307,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 147,
#   'Response': 0},
#  {'id': 128,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 25,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 23955,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 22,
#   'Response': 0},
#  {'id': 129,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 20,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 219,
#   'Response': 0},
#  {'id': 130,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 22371,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 50,
#   'Response': 0},
#  {'id': 131,
#   'Gender': 'Male',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 57389,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 155,
#   'Response': 1},
#  {'id': 132,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 30005,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 92,
#   'Response': 0},
#  {'id': 133,
#   'Gender': 'Male',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 37,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 32600,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 131,
#   'Response': 0},
#  {'id': 134,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 49,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31680,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 66,
#   'Response': 0},
#  {'id': 135,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40651,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 260,
#   'Response': 0},
#  {'id': 136,
#   'Gender': 'Female',
#   'Age': 43,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 19,
#   'Response': 1},
#  {'id': 137,
#   'Gender': 'Female',
#   'Age': 59,
#   'Driving_License': 1,
#   'Region_Code': 39,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32775,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 158,
#   'Response': 0},
#  {'id': 138,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 36,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 33638,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 22,
#   'Response': 0},
#  {'id': 139,
#   'Gender': 'Male',
#   'Age': 36,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 258,
#   'Response': 0},
#  {'id': 140,
#   'Gender': 'Male',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 29,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 62164,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 116,
#   'Response': 0},
#  {'id': 141,
#   'Gender': 'Female',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27528,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 117,
#   'Response': 0},
#  {'id': 142,
#   'Gender': 'Female',
#   'Age': 47,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 42080,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 62,
#   'Response': 0},
#  {'id': 143,
#   'Gender': 'Male',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 36202,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 193,
#   'Response': 0},
#  {'id': 144,
#   'Gender': 'Female',
#   'Age': 32,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 27320,
#   'Policy_Sales_Channel': 156,
#   'Vintage': 204,
#   'Response': 0},
#  {'id': 145,
#   'Gender': 'Male',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40511,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 212,
#   'Response': 0},
#  {'id': 146,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 56589,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 144,
#   'Response': 0},
#  {'id': 147,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 33780,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 246,
#   'Response': 0},
#  {'id': 148,
#   'Gender': 'Male',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 39,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 28329,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 78,
#   'Response': 0},
#  {'id': 149,
#   'Gender': 'Female',
#   'Age': 38,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34471,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 234,
#   'Response': 1},
#  {'id': 150,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 11,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 76651,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 258,
#   'Response': 0},
#  {'id': 151,
#   'Gender': 'Male',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 54385,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 206,
#   'Response': 0},
#  {'id': 152,
#   'Gender': 'Male',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 26732,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 282,
#   'Response': 0},
#  {'id': 153,
#   'Gender': 'Male',
#   'Age': 51,
#   'Driving_License': 1,
#   'Region_Code': 19,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 228,
#   'Response': 0},
#  {'id': 154,
#   'Gender': 'Male',
#   'Age': 53,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40397,
#   'Policy_Sales_Channel': 122,
#   'Vintage': 156,
#   'Response': 0},
#  {'id': 155,
#   'Gender': 'Female',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 22,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 34591,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 125,
#   'Response': 0},
#  {'id': 156,
#   'Gender': 'Female',
#   'Age': 49,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32771,
#   'Policy_Sales_Channel': 154,
#   'Vintage': 29,
#   'Response': 0},
#  {'id': 157,
#   'Gender': 'Female',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 54740,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 212,
#   'Response': 1},
#  {'id': 158,
#   'Gender': 'Male',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 35,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 25112,
#   'Policy_Sales_Channel': 154,
#   'Vintage': 221,
#   'Response': 0},
#  {'id': 159,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 47,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 28737,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 18,
#   'Response': 0},
#  {'id': 160,
#   'Gender': 'Female',
#   'Age': 31,
#   'Driving_License': 1,
#   'Region_Code': 15,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 25908,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 84,
#   'Response': 0},
#  {'id': 161,
#   'Gender': 'Male',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 41914,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 206,
#   'Response': 0},
#  {'id': 162,
#   'Gender': 'Male',
#   'Age': 70,
#   'Driving_License': 1,
#   'Region_Code': 25,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 230,
#   'Response': 0},
#  {'id': 163,
#   'Gender': 'Male',
#   'Age': 78,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 42462,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 54,
#   'Response': 0},
#  {'id': 164,
#   'Gender': 'Female',
#   'Age': 31,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 29395,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 123,
#   'Response': 0},
#  {'id': 165,
#   'Gender': 'Female',
#   'Age': 48,
#   'Driving_License': 1,
#   'Region_Code': 36,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 189,
#   'Response': 0},
#  {'id': 166,
#   'Gender': 'Male',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 29396,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 22,
#   'Response': 0},
#  {'id': 167,
#   'Gender': 'Female',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 44,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 37570,
#   'Policy_Sales_Channel': 156,
#   'Vintage': 258,
#   'Response': 1},
#  {'id': 168,
#   'Gender': 'Female',
#   'Age': 26,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 89282,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 101,
#   'Response': 0},
#  {'id': 169,
#   'Gender': 'Female',
#   'Age': 60,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 30386,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 114,
#   'Response': 0},
#  {'id': 170,
#   'Gender': 'Female',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31454,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 86,
#   'Response': 0},
#  {'id': 171,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 36,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 52462,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 243,
#   'Response': 0},
#  {'id': 172,
#   'Gender': 'Male',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 36,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 36352,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 13,
#   'Response': 0},
#  {'id': 173,
#   'Gender': 'Female',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 36282,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 237,
#   'Response': 0},
#  {'id': 174,
#   'Gender': 'Female',
#   'Age': 33,
#   'Driving_License': 1,
#   'Region_Code': 36,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40899,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 85,
#   'Response': 0},
#  {'id': 175,
#   'Gender': 'Male',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 35,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 23540,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 98,
#   'Response': 0},
#  {'id': 176,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 36,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 34527,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 67,
#   'Response': 0},
#  {'id': 177,
#   'Gender': 'Male',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 101021,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 49,
#   'Response': 0},
#  {'id': 178,
#   'Gender': 'Male',
#   'Age': 60,
#   'Driving_License': 1,
#   'Region_Code': 45,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 42888,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 229,
#   'Response': 0},
#  {'id': 179,
#   'Gender': 'Male',
#   'Age': 46,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 60478,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 128,
#   'Response': 1},
#  {'id': 180,
#   'Gender': 'Female',
#   'Age': 45,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
# ...
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 26968,
#   'Policy_Sales_Channel': 122,
#   'Vintage': 17,
#   'Response': 0},
#  {'id': 942,
#   'Gender': 'Male',
#   'Age': 35,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 37449,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 70,
#   'Response': 0},
#  {'id': 943,
#   'Gender': 'Female',
#   'Age': 42,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 43878,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 59,
#   'Response': 0},
#  {'id': 944,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 36,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 29430,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 271,
#   'Response': 0},
#  {'id': 945,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 7,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 49396,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 133,
#   'Response': 0},
#  {'id': 946,
#   'Gender': 'Female',
#   'Age': 42,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 23211,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 113,
#   'Response': 0},
#  {'id': 947,
#   'Gender': 'Male',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 15,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38356,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 258,
#   'Response': 0},
#  {'id': 948,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 37,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 30266,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 88,
#   'Response': 0},
#  {'id': 949,
#   'Gender': 'Male',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 36,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 41945,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 50,
#   'Response': 0},
#  {'id': 950,
#   'Gender': 'Female',
#   'Age': 46,
#   'Driving_License': 1,
#   'Region_Code': 26,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 157,
#   'Vintage': 142,
#   'Response': 1},
#  {'id': 951,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 45,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 21280,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 45,
#   'Response': 0},
#  {'id': 952,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 26,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 33459,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 153,
#   'Response': 0},
#  {'id': 953,
#   'Gender': 'Male',
#   'Age': 45,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 13895,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 113,
#   'Response': 0},
#  {'id': 954,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 65093,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 240,
#   'Response': 0},
#  {'id': 955,
#   'Gender': 'Male',
#   'Age': 57,
#   'Driving_License': 1,
#   'Region_Code': 39,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 49,
#   'Response': 0},
#  {'id': 956,
#   'Gender': 'Male',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 11,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 29587,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 187,
#   'Response': 0},
#  {'id': 957,
#   'Gender': 'Male',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 15,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 33666,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 242,
#   'Response': 1},
#  {'id': 958,
#   'Gender': 'Female',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 30354,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 232,
#   'Response': 0},
#  {'id': 959,
#   'Gender': 'Male',
#   'Age': 36,
#   'Driving_License': 1,
#   'Region_Code': 29,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 28075,
#   'Policy_Sales_Channel': 156,
#   'Vintage': 230,
#   'Response': 0},
#  {'id': 960,
#   'Gender': 'Female',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 45,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 27546,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 279,
#   'Response': 0},
#  {'id': 961,
#   'Gender': 'Female',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 30,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 35192,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 25,
#   'Response': 0},
#  {'id': 962,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 32978,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 112,
#   'Response': 0},
#  {'id': 963,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 59086,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 238,
#   'Response': 0},
#  {'id': 964,
#   'Gender': 'Male',
#   'Age': 33,
#   'Driving_License': 1,
#   'Region_Code': 15,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 35268,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 268,
#   'Response': 0},
#  {'id': 965,
#   'Gender': 'Male',
#   'Age': 35,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 23146,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 268,
#   'Response': 0},
#  {'id': 966,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 36341,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 65,
#   'Response': 0},
#  {'id': 967,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 42963,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 175,
#   'Response': 0},
#  {'id': 968,
#   'Gender': 'Male',
#   'Age': 47,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 24495,
#   'Policy_Sales_Channel': 7,
#   'Vintage': 284,
#   'Response': 0},
#  {'id': 969,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 12,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 23262,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 69,
#   'Response': 0},
#  {'id': 970,
#   'Gender': 'Male',
#   'Age': 33,
#   'Driving_License': 1,
#   'Region_Code': 36,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 26910,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 31,
#   'Response': 0},
#  {'id': 971,
#   'Gender': 'Male',
#   'Age': 34,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 31177,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 103,
#   'Response': 1},
#  {'id': 972,
#   'Gender': 'Male',
#   'Age': 52,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 50851,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 285,
#   'Response': 1},
#  {'id': 973,
#   'Gender': 'Male',
#   'Age': 32,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 30505,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 181,
#   'Response': 0},
#  {'id': 974,
#   'Gender': 'Male',
#   'Age': 40,
#   'Driving_License': 1,
#   'Region_Code': 8,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 49097,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 208,
#   'Response': 0},
#  {'id': 975,
#   'Gender': 'Male',
#   'Age': 57,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 11,
#   'Vintage': 269,
#   'Response': 0},
#  {'id': 976,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 47385,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 277,
#   'Response': 0},
#  {'id': 977,
#   'Gender': 'Male',
#   'Age': 33,
#   'Driving_License': 1,
#   'Region_Code': 10,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 21928,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 58,
#   'Response': 0},
#  {'id': 978,
#   'Gender': 'Female',
#   'Age': 67,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 42,
#   'Vintage': 138,
#   'Response': 0},
#  {'id': 979,
#   'Gender': 'Female',
#   'Age': 33,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 156,
#   'Vintage': 116,
#   'Response': 1},
#  {'id': 980,
#   'Gender': 'Male',
#   'Age': 48,
#   'Driving_License': 1,
#   'Region_Code': 27,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32645,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 182,
#   'Response': 0},
#  {'id': 981,
#   'Gender': 'Male',
#   'Age': 35,
#   'Driving_License': 1,
#   'Region_Code': 32,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34062,
#   'Policy_Sales_Channel': 163,
#   'Vintage': 236,
#   'Response': 1},
#  {'id': 982,
#   'Gender': 'Male',
#   'Age': 38,
#   'Driving_License': 1,
#   'Region_Code': 36,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 37742,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 295,
#   'Response': 1},
#  {'id': 983,
#   'Gender': 'Male',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 17,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 29625,
#   'Policy_Sales_Channel': 83,
#   'Vintage': 286,
#   'Response': 0},
#  {'id': 984,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 47,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 29431,
#   'Policy_Sales_Channel': 151,
#   'Vintage': 257,
#   'Response': 0},
#  {'id': 985,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 16,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 126,
#   'Response': 1},
#  {'id': 986,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 20804,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 204,
#   'Response': 0},
#  {'id': 987,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 16,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 145,
#   'Response': 0},
#  {'id': 988,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 47,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31231,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 175,
#   'Response': 0},
#  {'id': 989,
#   'Gender': 'Male',
#   'Age': 48,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32485,
#   'Policy_Sales_Channel': 124,
#   'Vintage': 12,
#   'Response': 1},
#  {'id': 990,
#   'Gender': 'Female',
#   'Age': 51,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 37768,
#   'Policy_Sales_Channel': 25,
#   'Vintage': 69,
#   'Response': 0},
#  {'id': 991,
#   'Gender': 'Female',
#   'Age': 43,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 30437,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 208,
#   'Response': 0},
#  {'id': 992,
#   'Gender': 'Male',
#   'Age': 66,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 240,
#   'Response': 0},
#  {'id': 993,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 3,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 22102,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 163,
#   'Response': 0},
#  {'id': 994,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 10,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 30517,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 125,
#   'Response': 0},
#  {'id': 995,
#   'Gender': 'Female',
#   'Age': 58,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 42064,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 163,
#   'Response': 0},
#  {'id': 996,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 35,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 41195,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 148,
#   'Response': 0},
#  {'id': 997,
#   'Gender': 'Male',
#   'Age': 31,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38881,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 120,
#   'Response': 0},
#  {'id': 998,
#   'Gender': 'Male',
#   'Age': 31,
#   'Driving_License': 1,
#   'Region_Code': 41,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 18987,
#   'Policy_Sales_Channel': 152,
#   'Vintage': 100,
#   'Response': 1},
#  {'id': 999,
#   'Gender': 'Female',
#   'Age': 43,
#   'Driving_License': 1,
#   'Region_Code': 28,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 55924,
#   'Policy_Sales_Channel': 26,
#   'Vintage': 216,
#   'Response': 1},
#  {'id': 1000,
#   'Gender': 'Female',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 46,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 29298,
#   'Policy_Sales_Channel': 160,
#   'Vintage': 37,
#   'Response': 0},
#  ...]

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://souvikpaul425:<password>@cluster0.i0rwmza.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github.

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)

# %%
# Load back data from mongodb

df = pd.DataFrame(list(collection.find()))
df.head(2)
# Out:
#                         _id  id Gender  Age  Driving_License  Region_Code  \
# 0  6824896a22eedacbb84a6e9b   1   Male   44                1           28
# 1  6824896a22eedacbb84a6e9c   2   Male   76                1            3
#
#    Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 0                   0   > 2 Years            Yes           40454
# 1                   0    1-2 Year             No           33536
#
#    Policy_Sales_Channel  Vintage  Response
# 0                    26      217         1
# 1                    26      183         0
